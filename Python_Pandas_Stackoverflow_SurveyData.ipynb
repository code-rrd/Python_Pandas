# %% [markdown]
# # Importing PANDAS

# %%
import pandas as pd

# %%
df = pd.read_csv("Downloads/data/survey_results_public.csv")
df.head()
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1             I am a student who is learning to code      Yes
# 1           2             I am a student who is learning to code       No
# 2           3  I am not primarily a developer, but I write co...      Yes
# 3           4                     I am a developer by profession       No
# 4           5                     I am a developer by profession      Yes
#
#                   OpenSourcer  \
# 0                       Never
# 1     Less than once per year
# 2                       Never
# 3                       Never
# 4  Once a month or more often
#
#                                           OpenSource  \
# 0  The quality of OSS and closed source software ...
# 1  The quality of OSS and closed source software ...
# 2  The quality of OSS and closed source software ...
# 3  The quality of OSS and closed source software ...
# 4  OSS is, on average, of HIGHER quality than pro...
#
# ...

# %% [markdown]
# # INDEXING

# %%
df = pd.read_csv("Downloads/data/survey_results_public.csv",index_col = "Respondent")
pd.set_option('display.max_column', 85)
df
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
# ...                                                       ...      ...
# 88377                                                     NaN      Yes
# 88601                                                     NaN       No
# 88802                                                     NaN       No
# 88816                                                     NaN       No
# 88863                                                     NaN      Yes
#
#                                                   OpenSourcer  \
# Respondent
# ...

# %%
df.shape
# Out:
# (88883, 84)

# %%
df.columns
# Out:
# Index(['MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource', 'Employment',
#        'Country', 'Student', 'EdLevel', 'UndergradMajor', 'EduOther',
#        'OrgSize', 'DevType', 'YearsCode', 'Age1stCode', 'YearsCodePro',
#        'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney', 'MgrWant', 'JobSeek',
#        'LastHireDate', 'LastInt', 'FizzBuzz', 'JobFactors', 'ResumeUpdate',
#        'CurrencySymbol', 'CurrencyDesc', 'CompTotal', 'CompFreq',
#        'ConvertedComp', 'WorkWeekHrs', 'WorkPlan', 'WorkChallenge',
#        'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev', 'CodeRevHrs', 'UnitTests',
#        'PurchaseHow', 'PurchaseWhat', 'LanguageWorkedWith',
#        'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
# ...

# %%
df_schema = pd.read_csv("Downloads/data/survey_results_schema.csv", index_col = "Column" )
pd.set_option('display.max_rows',85)
df_schema
# Out:
#                                                              QuestionText
# Column
# Respondent              Randomized respondent ID number (not in order ...
# MainBranch              Which of the following options best describes ...
# Hobbyist                                          Do you code as a hobby?
# OpenSourcer                   How often do you contribute to open source?
# OpenSource              How do you feel about the quality of open sour...
# Employment              Which of the following best describes your cur...
# Country                         In which country do you currently reside?
# Student                 Are you currently enrolled in a formal, degree...
# EdLevel                 Which of the following best describes the high...
# UndergradMajor          What was your main or most important field of ...
# EduOther                Which of the following types of non-degree edu...
# OrgSize                 Approximately how many people are employed by ...
# ...

# %%
df_schema.sort_index()
# Out:
#                                                              QuestionText
# Column
# Age                     What is your age (in years)? If you prefer not...
# Age1stCode              At what age did you write your first line of c...
# BetterLife              Do you think people born today will have a bet...
# BlockchainIs            Blockchain / cryptocurrency technology is prim...
# BlockchainOrg           How is your organization thinking about or imp...
# CareerSat               Overall, how satisfied are you with your caree...
# CodeRev                          Do you review code as part of your work?
# CodeRevHrs              On average, how many hours per week do you spe...
# CompFreq                 Is that compensation weekly, monthly, or yearly?
# CompTotal               What is your current total compensation (salar...
# Containers              How do you use containers (Docker, Open Contai...
# ConvertedComp           Salary converted to annual USD salaries using ...
# ...

# %%
df_schema.loc["YearsCode", "QuestionText"]
# Out:
# 'Including any education, how many years have you been coding?'

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 88883 entries, 1 to 88863
# Data columns (total 84 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   MainBranch              88331 non-null  object
#  1   Hobbyist                88883 non-null  object
#  2   OpenSourcer             88883 non-null  object
#  3   OpenSource              86842 non-null  object
#  4   Employment              87181 non-null  object
#  5   Country                 88751 non-null  object
#  6   Student                 87014 non-null  object
#  7   EdLevel                 86390 non-null  object
#  8   UndergradMajor          75614 non-null  object
#  9   EduOther                84260 non-null  object
#  10  OrgSize                 71791 non-null  object
#  11  DevType                 81335 non-null  object
#  12  YearsCode               87938 non-null  object
#  13  Age1stCode              87634 non-null  object
# ...

# %% [markdown]
# # Selecting Rows and columns

# %%
df['Hobbyist']
# Out:
# Respondent
# 1        Yes
# 2         No
# 3        Yes
# 4         No
# 5        Yes
#         ...
# 88377    Yes
# 88601     No
# 88802     No
# 88816     No
# 88863    Yes
# Name: Hobbyist, Length: 88883, dtype: object

# %%
df['Hobbyist'].value_counts()
# Out:
# Yes    71257
# No     17626
# Name: Hobbyist, dtype: int64

# %%
df[['Hobbyist','EdLevel']]
# Out:
#            Hobbyist                                            EdLevel
# Respondent
# 1               Yes                          Primary/elementary school
# 2                No  Secondary school (e.g. American high school, G...
# 3               Yes           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 4                No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 5               Yes           Bachelor’s degree (BA, BS, B.Eng., etc.)
# ...             ...                                                ...
# 88377           Yes                          Primary/elementary school
# 88601            No                                                NaN
# 88802            No                                                NaN
# 88816            No                                                NaN
# 88863           Yes                 Professional degree (JD, MD, etc.)
#
# [88883 rows x 2 columns]

# %%
df.iloc[1]
# Out:
# MainBranch                           I am a student who is learning to code
# Hobbyist                                                                 No
# OpenSourcer                                         Less than once per year
# OpenSource                The quality of OSS and closed source software ...
# Employment                               Not employed, but looking for work
# Country                                              Bosnia and Herzegovina
# Student                                                      Yes, full-time
# EdLevel                   Secondary school (e.g. American high school, G...
# UndergradMajor                                                          NaN
# EduOther                  Taken an online course in programming or softw...
# OrgSize                                                                 NaN
# DevType                   Developer, desktop or enterprise applications;...
# ...

# %%
df.loc[[1,10]]
# Out:
#                                         MainBranch Hobbyist  \
# Respondent
# 1           I am a student who is learning to code      Yes
# 10                  I am a developer by profession      Yes
#
#                            OpenSourcer  \
# Respondent
# 1                                Never
# 10          Once a month or more often
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 10          OSS is, on average, of HIGHER quality than pro...
#
#                                         Employment         Country Student  \
# Respondent
# 1           Not employed, and not looking for work  United Kingdom      No
# 10                              Employed full-time           India      No
#
#                                                 EdLevel UndergradMajor  \
# Respondent
# 1                             Primary/elementary school            NaN
# ...

# %%
df.iloc[[1,10]]
# Out:
#                                         MainBranch Hobbyist  \
# Respondent
# 2           I am a student who is learning to code       No
# 11                     I code primarily as a hobby      Yes
#
#                            OpenSourcer  \
# Respondent
# 2              Less than once per year
# 11          Once a month or more often
#
#                                                    OpenSource  \
# Respondent
# 2           The quality of OSS and closed source software ...
# 11          The quality of OSS and closed source software ...
#
#                                     Employment                 Country  \
# Respondent
# 2           Not employed, but looking for work  Bosnia and Herzegovina
# 11                                         NaN     Antigua and Barbuda
#
#                    Student                                            EdLevel  \
# Respondent
# 2           Yes, full-time  Secondary school (e.g. American high school, G...
# ...

# %% [markdown]
# *Employemnt type of Respondant 2

# %%
df.loc[2,"Employment"]
# Out:
# 'Not employed, but looking for work'

# %% [markdown]
# *What is Employment type of Respondant 3,6 ? In Which Country They Lived?

# %%
df.loc[[3,6],["Employment","Country"]]
# Out:
#                     Employment   Country
# Respondent
# 3           Employed full-time  Thailand
# 6           Employed full-time    Canada

# %% [markdown]
# *What is Education Level  of Respondant 3 to 6 ? In Which age they first code ?
#
# What is Primary Operating system in which they worked?
#
# NOTE ----> Slicing Value for 3 to 6 does not put in [ ] , so that 6 is included in DataFrame .
#             Putting slicing value in [ ] Parenthesis will give syntax error.
#             if you want to do slicing for Columns, then Columns name should not put in [ ].

# %%
df.loc[3:6,["EdLevel","Age1stCode","OpSys"]]
# Out:
#                                              EdLevel Age1stCode        OpSys
# Respondent
# 3           Bachelor’s degree (BA, BS, B.Eng., etc.)         22  Linux-based
# 4           Bachelor’s degree (BA, BS, B.Eng., etc.)         16      Windows
# 5           Bachelor’s degree (BA, BS, B.Eng., etc.)         14  Linux-based
# 6           Bachelor’s degree (BA, BS, B.Eng., etc.)         15      Windows

# %%
df.loc[3:6,"EdLevel":"Age1stCode"]
# Out:
#                                              EdLevel  \
# Respondent
# 3           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 4           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 5           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 6           Bachelor’s degree (BA, BS, B.Eng., etc.)
#
#                                                UndergradMajor  \
# Respondent
# 3                               Web development or web design
# 4           Computer science, computer engineering, or sof...
# 5           Computer science, computer engineering, or sof...
# 6                                   Mathematics or statistics
#
#                                                      EduOther  \
# Respondent
# 3           Taught yourself a new language, framework, or ...
# 4           Taken an online course in programming or softw...
# 5           Taken an online course in programming or softw...
# 6           Taken an online course in programming or softw...
#
# ...

# %% [markdown]
# # Filtering Rows / Columns

# %% [markdown]
# df["YearsCode"] > 5
#
#
# TypeError: '>' not supported between instances of 'str' and 'int'

# %%
(df["YearsCode"] > "5").value_counts()
# Out:
# False    67119
# True     21764
# Name: YearsCode, dtype: int64

# %% [markdown]
# How much Candidates have high Salary than 7000 USD
# what Education level & Programming Language knowledge  and which country belongs they to?  whose salary is higher than 7000  USD.

# %%
high_salary = df['ConvertedComp'] > 7000
high_salary.value_counts()
# Out:
# True     51905
# False    36978
# Name: ConvertedComp, dtype: int64

# %%
df.loc[high_salary, ["EdLevel","Country","LanguageWorkedWith"]]
# Out:
#                                                       EdLevel        Country  \
# Respondent
# 3                    Bachelor’s degree (BA, BS, B.Eng., etc.)       Thailand
# 4                    Bachelor’s degree (BA, BS, B.Eng., etc.)  United States
# 6                    Bachelor’s degree (BA, BS, B.Eng., etc.)         Canada
# 9           Some college/university study without earning ...    New Zealand
# 10                Master’s degree (MA, MS, M.Eng., MBA, etc.)          India
# ...                                                       ...            ...
# 88878                Bachelor’s degree (BA, BS, B.Eng., etc.)  United States
# 88879             Master’s degree (MA, MS, M.Eng., MBA, etc.)        Finland
# 88881             Master’s degree (MA, MS, M.Eng., MBA, etc.)        Austria
# 88882             Master’s degree (MA, MS, M.Eng., MBA, etc.)    Netherlands
# 88883                Bachelor’s degree (BA, BS, B.Eng., etc.)         Greece
#
# ...

# %% [markdown]
# How much Indians have salary more than 7000 USD ?

# %%
df.loc[high_salary, "Country"].value_counts()['India']
# Out:
# 2541

# %% [markdown]
# # Modifying Data

# %%
# df.columns = [x.upper() for x in df.columns]
# df.columns

# %%
df.rename(columns = {"ConvertedComp":"Salary"},inplace = True)
df
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
# ...                                                       ...      ...
# 88377                                                     NaN      Yes
# 88601                                                     NaN       No
# 88802                                                     NaN       No
# 88816                                                     NaN       No
# 88863                                                     NaN      Yes
#
#                                                   OpenSourcer  \
# Respondent
# ...

# %%
df["Hobbyist"].map({"Yes":True, "No":False})
# Out:
# Respondent
# 1         True
# 2        False
# 3         True
# 4        False
# 5         True
#          ...
# 88377     True
# 88601    False
# 88802    False
# 88816    False
# 88863     True
# Name: Hobbyist, Length: 88883, dtype: bool
